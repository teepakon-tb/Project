# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.feature_selection import mutual_info_classif

# โหลดข้อมูลจากไฟล์ CSV
df = pd.read_csv('UNSW_NB15_testing-set.csv')

X = df[['spkts', 'dpkts', 'sbytes', 'dbytes']]
y = df['label']

# หา Information Gain ของแต่ละ feature
ig_scores = mutual_info_classif(X, y, discrete_features=False)

# แสดง Information Gain ของแต่ละ feature
for feature, ig_score in zip(X.columns, ig_scores):
    print(f'Information Gain for {feature}: {ig_score}')

# ใช้ DecisionTreeClassifier
model = RandomForestClassifier()

# วนซ้ำโดยใช้ค่า random seed แต่ละครั้ง
for seed in [1, 20, 100, 200, 1000]:
    # แบ่งข้อมูลเป็นชุดฝึกและชุดทดสอบ
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

    # ใช้ DecisionTreeClassifier
    model.fit(X_train, y_train)

    # ทำนายค่า 'label' ด้วยชุดทดสอบ
    y_pred = model.predict(X_test)

    # ประเมินประสิทธิภาพ
    accuracy = metrics.accuracy_score(y_test, y_pred)
    print(f'Seed = {seed}, Accuracy: {accuracy}')

    # แสดง Confusion Matrix
    conf_matrix = metrics.confusion_matrix(y_test, y_pred)
    print('Confusion Matrix:')
    print(conf_matrix)

    # แสดง Classification Report
    class_report = metrics.classification_report(y_test, y_pred)
    print('Classification Report:')
    print(class_report)
# Out:
# Information Gain for spkts: 0.1777213647109428
# Information Gain for dpkts: 0.2732509388568858
# Information Gain for sbytes: 0.4666672591715322
# Information Gain for dbytes: 0.3710325662291214
# Seed = 1, Accuracy: 0.9423992700105507
# Confusion Matrix:
# [[10140  1027]
#  [  993 22909]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91     11167
#            1       0.96      0.96      0.96     23902
#
#     accuracy                           0.94     35069
#    macro avg       0.93      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
#
# Seed = 20, Accuracy: 0.9412871767087742
# Confusion Matrix:
# [[10023  1136]
#  [  923 22987]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     11159
#            1       0.95      0.96      0.96     23910
#
#     accuracy                           0.94     35069
#    macro avg       0.93      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
#
# Seed = 100, Accuracy: 0.9414012375602384
# Confusion Matrix:
# [[ 9993  1206]
#  [  849 23021]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91     11199
#            1       0.95      0.96      0.96     23870
#
#     accuracy                           0.94     35069
#    macro avg       0.94      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
#
# Seed = 200, Accuracy: 0.9425133308620148
# Confusion Matrix:
# [[ 9988  1213]
#  [  803 23065]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91     11201
#            1       0.95      0.97      0.96     23868
#
#     accuracy                           0.94     35069
#    macro avg       0.94      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
#
# Seed = 1000, Accuracy: 0.9428555134164076
# Confusion Matrix:
# [[10093  1167]
#  [  837 22972]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     11260
#            1       0.95      0.96      0.96     23809
#
#     accuracy                           0.94     35069
#    macro avg       0.94      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
