# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.feature_selection import mutual_info_classif

# โหลดข้อมูลจากไฟล์ CSV
df = pd.read_csv('UNSW_NB15_testing-set.csv')

X = df[['spkts', 'dpkts', 'sbytes', 'dbytes']]
y = df['label']

# หา Information Gain ของแต่ละ feature
ig_scores = mutual_info_classif(X, y, discrete_features=False)

# แสดง Information Gain ของแต่ละ feature
for feature, ig_score in zip(X.columns, ig_scores):
    print(f'Information Gain for {feature}: {ig_score}')

# ใช้ DecisionTreeClassifier
model = DecisionTreeClassifier()

# วนซ้ำโดยใช้ค่า random seed แต่ละครั้ง
for seed in [1, 20, 100, 200, 1000]:
    # แบ่งข้อมูลเป็นชุดฝึกและชุดทดสอบ
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

    # ใช้ DecisionTreeClassifier
    model.fit(X_train, y_train)

    # ทำนายค่า 'label' ด้วยชุดทดสอบ
    y_pred = model.predict(X_test)

    # ประเมินประสิทธิภาพ
    accuracy = metrics.accuracy_score(y_test, y_pred)
    print(f'Seed = {seed}, Accuracy: {accuracy}')

    # แสดง Confusion Matrix
    conf_matrix = metrics.confusion_matrix(y_test, y_pred)
    print('Confusion Matrix:')
    print(conf_matrix)

    # แสดง Classification Report
    class_report = metrics.classification_report(y_test, y_pred)
    print('Classification Report:')
    print(class_report)
# Out:
# Information Gain for spkts: 0.17811607326328338
# Information Gain for dpkts: 0.27323956490481716
# Information Gain for sbytes: 0.4666152374667436
# Information Gain for dbytes: 0.3722760636416238
# Seed = 1, Accuracy: 0.9407453876643189
# Confusion Matrix:
# [[10051  1116]
#  [  962 22940]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91     11167
#            1       0.95      0.96      0.96     23902
#
#     accuracy                           0.94     35069
#    macro avg       0.93      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
#
# Seed = 20, Accuracy: 0.9389489292537568
# Confusion Matrix:
# [[10059  1100]
#  [ 1041 22869]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90     11159
#            1       0.95      0.96      0.96     23910
#
#     accuracy                           0.94     35069
#    macro avg       0.93      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
#
# Seed = 100, Accuracy: 0.9382075337192393
# Confusion Matrix:
# [[10161  1038]
#  [ 1129 22741]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90     11199
#            1       0.96      0.95      0.95     23870
#
#     accuracy                           0.94     35069
#    macro avg       0.93      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
#
# Seed = 200, Accuracy: 0.9402891442584619
# Confusion Matrix:
# [[10035  1166]
#  [  928 22940]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     11201
#            1       0.95      0.96      0.96     23868
#
#     accuracy                           0.94     35069
#    macro avg       0.93      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
#
# Seed = 1000, Accuracy: 0.9402606290455958
# Confusion Matrix:
# [[10134  1126]
#  [  969 22840]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91     11260
#            1       0.95      0.96      0.96     23809
#
#     accuracy                           0.94     35069
#    macro avg       0.93      0.93      0.93     35069
# weighted avg       0.94      0.94      0.94     35069
